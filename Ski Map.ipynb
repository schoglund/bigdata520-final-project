# %% [markdown]
# # Ski Resort Map
# Use Folium, a Python wrapper for the Javascript library called Leaflet, to construct a map of the 8 ski resorts I analyzed with a week-to-week slider that visualizes the `overall_resort_score`.

# %%
import pandas as pd
import os
import glob
import fastparquet
import folium
from folium.plugins import TimestampedGeoJson
import calendar
import datetime

# %% [markdown]
# ## Reading in the Data
# I used Azure CLI and scp commands to transfer my "weather_scored" parquet file to my local file system so I can work here.

# %%
loc_lookup = []
for file in glob.glob('data/*_new.csv'):
    d = pd.read_csv(file)

    locs = d[['ski_resort', 'us_region', 'latitude', 'longitude', 'original_timezone']].drop_duplicates()
    loc_lookup.append(locs)

loc_lookup = pd.concat(loc_lookup)

# %%
loc_lookup
# Out:
#                    ski_resort            us_region  latitude  longitude  \
# 0    The Summit at Snoqualmie                  PNW    47.424   -121.417
# 286              Mt. Bachelor                  PNW    44.002   -121.678
# 572            Boyne Mountain              Midwest    45.159    -84.939
# 0             Boyne Highlands              Midwest    45.469    -84.922
# 0            Mammoth Mountain  Northern California    37.631   -119.032
# 286           Sierra-at-Tahoe  Northern California    38.800   -120.081
# 572           Copper Mountain              Rockies    38.487   -105.766
# 858                  Snowbird              Rockies    40.581   -111.656
#
#        original_timezone
# 0    America/Los_Angeles
# 286  America/Los_Angeles
# 572      America/Detroit
# 0        America/Detroit
# 0    America/Los_Angeles
# 286  America/Los_Angeles
# 572       America/Denver
# 858       America/Denver

# %%
pf = fastparquet.ParquetFile("data/weather_scored/")
df = pf.to_pandas()

# %%
ski_weather_data = df.merge(loc_lookup, how="left", on="ski_resort")

# %% [markdown]
# ## Creating the Map

# %%
m = folium.Map(location=[39.83, -98.58], zoom_start=5, tiles="cartodb positron")

# %%
for _, row in loc_lookup.iterrows():
    popup_text = f"Region: {row['us_region']}\nTimezone: {row['original_timezone']}"

    folium.Marker(
        location=[(row['latitude']), row['longitude']],
        tooltip=row['ski_resort'],
        popup=popup_text,
        icon=folium.Icon(icon="person-skiing", prefix="fa", )
    ).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0d26de8be509126ad9848fe3b19e0ebf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0d26de8be509126ad9848fe3b19e0ebf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0d26de8be509126ad9848fe3b19e0ebf = L.map(
#                 &quot;map_0d26de8be509126ad9848fe3b19e0ebf&quot;,
#                 {
#                     center: [39.83, -98.58],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7891a17a2c4345d08c567ccbbdddeda4 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7891a17a2c4345d08c567ccbbdddeda4.addTo(map_0d26de8be509126ad9848fe3b19e0ebf);
#
#
#             var marker_6210470459da5e4079a339d2499ae1ae = L.marker(
#                 [47.424, -121.417],
#                 {
# }
#             ).addTo(map_0d26de8be509126ad9848fe3b19e0ebf);
#
#
#             var icon_8d44fc2c9e277c9ae59e2c65eb915aab = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;person-skiing&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_842e9c993eaf20d0ba4e725ee65c7ecd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_17e575649aecc85c78dd8533fc0ddfc7 = $(`&lt;div id=&quot;html_17e575649aecc85c78dd8533fc0ddfc7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Region: PNW Timezone: America/Los_Angeles&lt;/div&gt;`)[0];
#                 popup_842e9c993eaf20d0ba4e725ee65c7ecd.setContent(html_17e575649aecc85c78dd8533fc0ddfc7);
#
#
#
#         marker_6210470459da5e4079a339d2499ae1ae.bindPopup(popup_842e9c993eaf20d0ba4e725ee65c7ecd)
#         ;
#
#
#
#
#             marker_6210470459da5e4079a339d2499ae1ae.bindTooltip(
#                 `&lt;div&gt;
#                      The Summit at Snoqualmie
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_6210470459da5e4079a339d2499ae1ae.setIcon(icon_8d44fc2c9e277c9ae59e2c65eb915aab);
#
#
#             var marker_21077eaabb0690e4c579b572c6b5b0e0 = L.marker(
#                 [44.002, -121.678],
#                 {
# }
#             ).addTo(map_0d26de8be509126ad9848fe3b19e0ebf);
#
#
#             var icon_3d6cc24fa4d5d243a8462c41cbb79fbe = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;person-skiing&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b5ef3db0bc3e7803f726a8b28213c4c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6bf1b3541155cce6b40759d9bfd0b88f = $(`&lt;div id=&quot;html_6bf1b3541155cce6b40759d9bfd0b88f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Region: PNW Timezone: America/Los_Angeles&lt;/div&gt;`)[0];
#                 popup_b5ef3db0bc3e7803f726a8b28213c4c0.setContent(html_6bf1b3541155cce6b40759d9bfd0b88f);
#
#
#
#         marker_21077eaabb0690e4c579b572c6b5b0e0.bindPopup(popup_b5ef3db0bc3e7803f726a8b28213c4c0)
#         ;
#
#
#
#
#             marker_21077eaabb0690e4c579b572c6b5b0e0.bindTooltip(
#                 `&lt;div&gt;
#                      Mt. Bachelor
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_21077eaabb0690e4c579b572c6b5b0e0.setIcon(icon_3d6cc24fa4d5d243a8462c41cbb79fbe);
#
#
#             var marker_8f0220e0aca7037f4fe9dce4b6f91686 = L.marker(
#                 [45.159, -84.939],
#                 {
# }
#             ).addTo(map_0d26de8be509126ad9848fe3b19e0ebf);
#
#
#             var icon_67d689db6579fc8ce5be00c7c9cb5a2e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;person-skiing&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8d8eb308722ee3ae6d39e3f4e1375feb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_765a81ea7f1633c74f74d05dd051fb4c = $(`&lt;div id=&quot;html_765a81ea7f1633c74f74d05dd051fb4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Region: Midwest Timezone: America/Detroit&lt;/div&gt;`)[0];

# %% [markdown]
# Next Steps:
# 1. get the top 3 ski resorts for each week based on `overall_resort_score`
# 2. Convert the `week_num`'s to actual 2026 date ranges.
# 3. Make a dictionary to capture the markers with lat/long of the rankings for each `week_num` so it can link to the slider via `TimeSliderChoropleth`. The top 1 should have a gold-colored icon, 2nd should have a silver-colored icon, 3rd should have a bronze-colored icon, and everyone else should have a light gray to give the impression it's grayed out yet still visible. Also, the tooltip should still say the resort's name. The popup should give info on what it's `overall_resort_score` is along with what weather condition you can expect (`weather_main`). If I can give a title to the graph or slider, I would say it's "Week 2: MM-DD-YYYY to MM-DD-YYYY" and fill in the 2025-26 actual dates.

# %% [markdown]
# Style ideas: color code the top 3 with gold, silver, and bronze icons when creating Markers.

# %%
ski_weather_data['rank'] = ski_weather_data.groupby('week_num')['overall_resort_score'].rank(ascending=False)

# %% [markdown]
# Convert the `week_num`'s to actual 2025-26 season date ranges:

# %%
cal = calendar.Calendar()
month_range = [(2025, 12)]
end_month = 4
end_year = 2026
month_range.extend([(end_year, m) for m in range(1,end_month+1)])

# %%
dates_2526 = {}
week_num = 1
for yr, mo in month_range:
    print(f"Year: {yr}\t Month:{mo}")
    for i, wk in enumerate(cal.monthdatescalendar(yr, mo)):
        # just want to grab the lists of datetime objects where the first element falls within the given 'mo' AND
        # want to ignore the last couple weeks in April since those dates fall beyond the assumed ski season
        if wk[0].month != mo or (mo == end_month and i > 2):
            continue
    
        print(f"This is Week #{week_num}: {wk}")
        dates_2526[week_num] = wk
        week_num += 1
# Out:
# Year: 2025	 Month:12
# This is Week #1: [datetime.date(2025, 12, 1), datetime.date(2025, 12, 2), datetime.date(2025, 12, 3), datetime.date(2025, 12, 4), datetime.date(2025, 12, 5), datetime.date(2025, 12, 6), datetime.date(2025, 12, 7)]
# This is Week #2: [datetime.date(2025, 12, 8), datetime.date(2025, 12, 9), datetime.date(2025, 12, 10), datetime.date(2025, 12, 11), datetime.date(2025, 12, 12), datetime.date(2025, 12, 13), datetime.date(2025, 12, 14)]
# This is Week #3: [datetime.date(2025, 12, 15), datetime.date(2025, 12, 16), datetime.date(2025, 12, 17), datetime.date(2025, 12, 18), datetime.date(2025, 12, 19), datetime.date(2025, 12, 20), datetime.date(2025, 12, 21)]
# This is Week #4: [datetime.date(2025, 12, 22), datetime.date(2025, 12, 23), datetime.date(2025, 12, 24), datetime.date(2025, 12, 25), datetime.date(2025, 12, 26), datetime.date(2025, 12, 27), datetime.date(2025, 12, 28)]
# This is Week #5: [datetime.date(2025, 12, 29), datetime.date(2025, 12, 30), datetime.date(2025, 12, 31), datetime.date(2026, 1, 1), datetime.date(2026, 1, 2), datetime.date(2026, 1, 3), datetime.date(2026, 1, 4)]
# Year: 2026	 Month:1
# This is Week #6: [datetime.date(2026, 1, 5), datetime.date(2026, 1, 6), datetime.date(2026, 1, 7), datetime.date(2026, 1, 8), datetime.date(2026, 1, 9), datetime.date(2026, 1, 10), datetime.date(2026, 1, 11)]
# This is Week #7: [datetime.date(2026, 1, 12), datetime.date(2026, 1, 13), datetime.date(2026, 1, 14), datetime.date(2026, 1, 15), datetime.date(2026, 1, 16), datetime.date(2026, 1, 17), datetime.date(2026, 1, 18)]
# This is Week #8: [datetime.date(2026, 1, 19), datetime.date(2026, 1, 20), datetime.date(2026, 1, 21), datetime.date(2026, 1, 22), datetime.date(2026, 1, 23), datetime.date(2026, 1, 24), datetime.date(2026, 1, 25)]
# This is Week #9: [datetime.date(2026, 1, 26), datetime.date(2026, 1, 27), datetime.date(2026, 1, 28), datetime.date(2026, 1, 29), datetime.date(2026, 1, 30), datetime.date(2026, 1, 31), datetime.date(2026, 2, 1)]
# Year: 2026	 Month:2
# This is Week #10: [datetime.date(2026, 2, 2), datetime.date(2026, 2, 3), datetime.date(2026, 2, 4), datetime.date(2026, 2, 5), datetime.date(2026, 2, 6), datetime.date(2026, 2, 7), datetime.date(2026, 2, 8)]
# This is Week #11: [datetime.date(2026, 2, 9), datetime.date(2026, 2, 10), datetime.date(2026, 2, 11), datetime.date(2026, 2, 12), datetime.date(2026, 2, 13), datetime.date(2026, 2, 14), datetime.date(2026, 2, 15)]
# This is Week #12: [datetime.date(2026, 2, 16), datetime.date(2026, 2, 17), datetime.date(2026, 2, 18), datetime.date(2026, 2, 19), datetime.date(2026, 2, 20), datetime.date(2026, 2, 21), datetime.date(2026, 2, 22)]
# This is Week #13: [datetime.date(2026, 2, 23), datetime.date(2026, 2, 24), datetime.date(2026, 2, 25), datetime.date(2026, 2, 26), datetime.date(2026, 2, 27), datetime.date(2026, 2, 28), datetime.date(2026, 3, 1)]
# Year: 2026	 Month:3
# This is Week #14: [datetime.date(2026, 3, 2), datetime.date(2026, 3, 3), datetime.date(2026, 3, 4), datetime.date(2026, 3, 5), datetime.date(2026, 3, 6), datetime.date(2026, 3, 7), datetime.date(2026, 3, 8)]
# This is Week #15: [datetime.date(2026, 3, 9), datetime.date(2026, 3, 10), datetime.date(2026, 3, 11), datetime.date(2026, 3, 12), datetime.date(2026, 3, 13), datetime.date(2026, 3, 14), datetime.date(2026, 3, 15)]
# This is Week #16: [datetime.date(2026, 3, 16), datetime.date(2026, 3, 17), datetime.date(2026, 3, 18), datetime.date(2026, 3, 19), datetime.date(2026, 3, 20), datetime.date(2026, 3, 21), datetime.date(2026, 3, 22)]
# This is Week #17: [datetime.date(2026, 3, 23), datetime.date(2026, 3, 24), datetime.date(2026, 3, 25), datetime.date(2026, 3, 26), datetime.date(2026, 3, 27), datetime.date(2026, 3, 28), datetime.date(2026, 3, 29)]
# This is Week #18: [datetime.date(2026, 3, 30), datetime.date(2026, 3, 31), datetime.date(2026, 4, 1), datetime.date(2026, 4, 2), datetime.date(2026, 4, 3), datetime.date(2026, 4, 4), datetime.date(2026, 4, 5)]
# Year: 2026	 Month:4
# This is Week #19: [datetime.date(2026, 4, 6), datetime.date(2026, 4, 7), datetime.date(2026, 4, 8), datetime.date(2026, 4, 9), datetime.date(2026, 4, 10), datetime.date(2026, 4, 11), datetime.date(2026, 4, 12)]
# This is Week #20: [datetime.date(2026, 4, 13), datetime.date(2026, 4, 14), datetime.date(2026, 4, 15), datetime.date(2026, 4, 16), datetime.date(2026, 4, 17), datetime.date(2026, 4, 18), datetime.date(2026, 4, 19)]

# %%
dates_2526[4]
# Out:
# [datetime.date(2025, 12, 22),
#  datetime.date(2025, 12, 23),
#  datetime.date(2025, 12, 24),
#  datetime.date(2025, 12, 25),
#  datetime.date(2025, 12, 26),
#  datetime.date(2025, 12, 27),
#  datetime.date(2025, 12, 28)]

# %% [markdown]
# Formatting a GeoJSON dictionary to get converted to JavaScript in `TimestampedGeoJson()`:

# %%
geojson_data = {
    'type': 'FeatureCollection'
}
feature_data = []

for _, dp in ski_weather_data.iterrows():
    if dp['weather_main'] == "Clear":
        weather_text = "be"
    else:
        weather_text = "have"

    if str(dp['week_num'])[-1] == 1:
        week_text = "st"
    elif str(dp['week_num'])[-1] == 2:
        week_text = "nd"
    elif str(dp['week_num'])[-1] == 3:
        week_text = "rd"
    else:
        week_text = "th"

    # get the 2025-26 actual dates for the week in question
    date_list = dates_2526[dp['week_num']]
    first_date = date_list[0].strftime("%b %d, %Y")
    last_date = date_list[-1].strftime("%b %d, %Y")
    date_list_iso = [d.strftime("%Y-%m-%d") for d in date_list]

    # figure out the selected_color based on the rank
    if dp['rank'] == 1:
        selected_color = '#EFBF04' # gold
    elif dp['rank'] == 2:
        selected_color = '#A9A9A9' # silver
    elif dp['rank'] == 3:
        selected_color = '#CD7F32' # bronze
    else:
        selected_color = '#FFFFFF' # white

    popup_text = f"<h1>{dp['ski_resort']}</h1><h2>Score: <b>{dp['overall_resort_score']:.2f}</b>/100</h2><br>In the {dp['us_region']} region, you can expect the weather to {weather_text} <b>{dp['weather_main']}</b> during the {dp['week_num']}{week_text} week of ski season, which is <b> {first_date} to {last_date}</b>."


    row = {
        'type': 'Feature',
        'geometry': {
            'type': 'Point',
            'coordinates': [dp['longitude'], dp['latitude']]
        },
        'properties': {
            'times': date_list_iso,
            'icon': 'circle',
            'style': {
                'color': selected_color,
                'radius': 20
            },
            'tooltip': popup_text
        }
    }

    feature_data.append(row.copy())

# add this list of features to geojson_data dictionary
geojson_data['features'] = feature_data

# %%
geojson_data
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-121.417, 47.424]},
#    'properties': {'times': ['2026-01-12',
#      '2026-01-13',
#      '2026-01-14',
#      '2026-01-15',
#      '2026-01-16',
#      '2026-01-17',
#      '2026-01-18'],
#     'icon': 'circle',
#     'style': {'color': '#A9A9A9', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>The Summit at Snoqualmie</h1><h2>Score: <b>62.57</b>/100</h2><br>In the PNW region, you can expect the weather to have <b>Clouds</b> during the 7th week of ski season, which is <b> Jan 12, 2026 to Jan 18, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.922, 45.469]},
#    'properties': {'times': ['2026-03-23',
#      '2026-03-24',
#      '2026-03-25',
#      '2026-03-26',
#      '2026-03-27',
#      '2026-03-28',
#      '2026-03-29'],
#     'icon': 'circle',
#     'style': {'color': '#EFBF04', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Boyne Highlands</h1><h2>Score: <b>62.10</b>/100</h2><br>In the Midwest region, you can expect the weather to have <b>Clouds</b> during the 17th week of ski season, which is <b> Mar 23, 2026 to Mar 29, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-119.032, 37.631]},
#    'properties': {'times': ['2026-02-02',
#      '2026-02-03',
#      '2026-02-04',
#      '2026-02-05',
#      '2026-02-06',
#      '2026-02-07',
#      '2026-02-08'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Mammoth Mountain</h1><h2>Score: <b>49.55</b>/100</h2><br>In the Northern California region, you can expect the weather to be <b>Clear</b> during the 10th week of ski season, which is <b> Feb 02, 2026 to Feb 08, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.939, 45.159]},
#    'properties': {'times': ['2026-03-23',
#      '2026-03-24',
#      '2026-03-25',
#      '2026-03-26',
#      '2026-03-27',
#      '2026-03-28',
#      '2026-03-29'],
#     'icon': 'circle',
#     'style': {'color': '#A9A9A9', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Boyne Mountain</h1><h2>Score: <b>61.94</b>/100</h2><br>In the Midwest region, you can expect the weather to have <b>Clouds</b> during the 17th week of ski season, which is <b> Mar 23, 2026 to Mar 29, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-119.032, 37.631]},
#    'properties': {'times': ['2026-01-05',
#      '2026-01-06',
#      '2026-01-07',
#      '2026-01-08',
#      '2026-01-09',
#      '2026-01-10',
#      '2026-01-11'],
#     'icon': 'circle',
#     'style': {'color': '#A9A9A9', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Mammoth Mountain</h1><h2>Score: <b>56.81</b>/100</h2><br>In the Northern California region, you can expect the weather to have <b>Clouds</b> during the 6th week of ski season, which is <b> Jan 05, 2026 to Jan 11, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-121.417, 47.424]},
#    'properties': {'times': ['2026-01-19',
#      '2026-01-20',
#      '2026-01-21',
#      '2026-01-22',
#      '2026-01-23',
#      '2026-01-24',
#      '2026-01-25'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>The Summit at Snoqualmie</h1><h2>Score: <b>46.71</b>/100</h2><br>In the PNW region, you can expect the weather to have <b>Haze</b> during the 8th week of ski season, which is <b> Jan 19, 2026 to Jan 25, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-111.656, 40.581]},
#    'properties': {'times': ['2026-04-13',
#      '2026-04-14',
#      '2026-04-15',
#      '2026-04-16',
#      '2026-04-17',
#      '2026-04-18',
#      '2026-04-19'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Snowbird</h1><h2>Score: <b>39.38</b>/100</h2><br>In the Rockies region, you can expect the weather to have <b>Clouds</b> during the 20th week of ski season, which is <b> Apr 13, 2026 to Apr 19, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-105.766, 38.487]},
#    'properties': {'times': ['2026-03-02',
#      '2026-03-03',
#      '2026-03-04',
#      '2026-03-05',
#      '2026-03-06',
#      '2026-03-07',
#      '2026-03-08'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Copper Mountain</h1><h2>Score: <b>43.74</b>/100</h2><br>In the Rockies region, you can expect the weather to be <b>Clear</b> during the 14th week of ski season, which is <b> Mar 02, 2026 to Mar 08, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-111.656, 40.581]},
#    'properties': {'times': ['2025-12-08',
#      '2025-12-09',
#      '2025-12-10',
#      '2025-12-11',
#      '2025-12-12',
#      '2025-12-13',
#      '2025-12-14'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Snowbird</h1><h2>Score: <b>32.39</b>/100</h2><br>In the Rockies region, you can expect the weather to have <b>Clouds</b> during the 2th week of ski season, which is <b> Dec 08, 2025 to Dec 14, 2025</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-111.656, 40.581]},
#    'properties': {'times': ['2026-01-19',
#      '2026-01-20',
#      '2026-01-21',
#      '2026-01-22',
#      '2026-01-23',
#      '2026-01-24',
#      '2026-01-25'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Snowbird</h1><h2>Score: <b>32.50</b>/100</h2><br>In the Rockies region, you can expect the weather to have <b>Clouds</b> during the 8th week of ski season, which is <b> Jan 19, 2026 to Jan 25, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.939, 45.159]},
#    'properties': {'times': ['2026-02-09',
#      '2026-02-10',
#      '2026-02-11',
#      '2026-02-12',
#      '2026-02-13',
#      '2026-02-14',
#      '2026-02-15'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Boyne Mountain</h1><h2>Score: <b>39.60</b>/100</h2><br>In the Midwest region, you can expect the weather to have <b>Clouds</b> during the 11th week of ski season, which is <b> Feb 09, 2026 to Feb 15, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-119.032, 37.631]},
#    'properties': {'times': ['2025-12-29',
#      '2025-12-30',
#      '2025-12-31',
#      '2026-01-01',
#      '2026-01-02',
#      '2026-01-03',
#      '2026-01-04'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Mammoth Mountain</h1><h2>Score: <b>43.90</b>/100</h2><br>In the Northern California region, you can expect the weather to be <b>Clear</b> during the 5th week of ski season, which is <b> Dec 29, 2025 to Jan 04, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.939, 45.159]},
#    'properties': {'times': ['2026-03-30',
#      '2026-03-31',
#      '2026-04-01',
#      '2026-04-02',
#      '2026-04-03',
#      '2026-04-04',
#      '2026-04-05'],
#     'icon': 'circle',
#     'style': {'color': '#CD7F32', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Boyne Mountain</h1><h2>Score: <b>55.07</b>/100</h2><br>In the Midwest region, you can expect the weather to have <b>Clouds</b> during the 18th week of ski season, which is <b> Mar 30, 2026 to Apr 05, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-119.032, 37.631]},
#    'properties': {'times': ['2026-03-30',
#      '2026-03-31',
#      '2026-04-01',
#      '2026-04-02',
#      '2026-04-03',
#      '2026-04-04',
#      '2026-04-05'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Mammoth Mountain</h1><h2>Score: <b>49.23</b>/100</h2><br>In the Northern California region, you can expect the weather to be <b>Clear</b> during the 18th week of ski season, which is <b> Mar 30, 2026 to Apr 05, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-120.081, 38.8]},
#    'properties': {'times': ['2026-01-05',
#      '2026-01-06',
#      '2026-01-07',
#      '2026-01-08',
#      '2026-01-09',
#      '2026-01-10',
#      '2026-01-11'],
#     'icon': 'circle',
#     'style': {'color': '#EFBF04', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Sierra-at-Tahoe</h1><h2>Score: <b>71.01</b>/100</h2><br>In the Northern California region, you can expect the weather to be <b>Clear</b> during the 6th week of ski season, which is <b> Jan 05, 2026 to Jan 11, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.939, 45.159]},
#    'properties': {'times': ['2026-01-05',
#      '2026-01-06',
#      '2026-01-07',
#      '2026-01-08',
#      '2026-01-09',
#      '2026-01-10',
#      '2026-01-11'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Boyne Mountain</h1><h2>Score: <b>36.39</b>/100</h2><br>In the Midwest region, you can expect the weather to have <b>Clouds</b> during the 6th week of ski season, which is <b> Jan 05, 2026 to Jan 11, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-120.081, 38.8]},
#    'properties': {'times': ['2026-02-02',
#      '2026-02-03',
#      '2026-02-04',
#      '2026-02-05',
#      '2026-02-06',
#      '2026-02-07',
#      '2026-02-08'],
#     'icon': 'circle',
#     'style': {'color': '#EFBF04', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Sierra-at-Tahoe</h1><h2>Score: <b>57.57</b>/100</h2><br>In the Northern California region, you can expect the weather to be <b>Clear</b> during the 10th week of ski season, which is <b> Feb 02, 2026 to Feb 08, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.922, 45.469]},
#    'properties': {'times': ['2026-01-05',
#      '2026-01-06',
#      '2026-01-07',
#      '2026-01-08',
#      '2026-01-09',
#      '2026-01-10',
#      '2026-01-11'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Boyne Highlands</h1><h2>Score: <b>45.03</b>/100</h2><br>In the Midwest region, you can expect the weather to have <b>Clouds</b> during the 6th week of ski season, which is <b> Jan 05, 2026 to Jan 11, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.922, 45.469]},
#    'properties': {'times': ['2026-04-13',
#      '2026-04-14',
#      '2026-04-15',
#      '2026-04-16',
#      '2026-04-17',
#      '2026-04-18',
#      '2026-04-19'],
#     'icon': 'circle',
#     'style': {'color': '#EFBF04', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Boyne Highlands</h1><h2>Score: <b>60.64</b>/100</h2><br>In the Midwest region, you can expect the weather to be <b>Clear</b> during the 20th week of ski season, which is <b> Apr 13, 2026 to Apr 19, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-120.081, 38.8]},
#    'properties': {'times': ['2026-02-16',
#      '2026-02-17',
#      '2026-02-18',
#      '2026-02-19',
#      '2026-02-20',
#      '2026-02-21',
#      '2026-02-22'],
#     'icon': 'circle',
#     'style': {'color': '#CD7F32', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Sierra-at-Tahoe</h1><h2>Score: <b>58.51</b>/100</h2><br>In the Northern California region, you can expect the weather to have <b>Snow</b> during the 12th week of ski season, which is <b> Feb 16, 2026 to Feb 22, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-119.032, 37.631]},
#    'properties': {'times': ['2026-02-09',
#      '2026-02-10',
#      '2026-02-11',
#      '2026-02-12',
#      '2026-02-13',
#      '2026-02-14',
#      '2026-02-15'],
#     'icon': 'circle',
#     'style': {'color': '#EFBF04', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Mammoth Mountain</h1><h2>Score: <b>59.31</b>/100</h2><br>In the Northern California region, you can expect the weather to be <b>Clear</b> during the 11th week of ski season, which is <b> Feb 09, 2026 to Feb 15, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-111.656, 40.581]},
#    'properties': {'times': ['2026-02-16',
#      '2026-02-17',
#      '2026-02-18',
#      '2026-02-19',
#      '2026-02-20',
#      '2026-02-21',
#      '2026-02-22'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Snowbird</h1><h2>Score: <b>30.88</b>/100</h2><br>In the Rockies region, you can expect the weather to have <b>Clouds</b> during the 12th week of ski season, which is <b> Feb 16, 2026 to Feb 22, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-120.081, 38.8]},
#    'properties': {'times': ['2026-01-26',
#      '2026-01-27',
#      '2026-01-28',
#      '2026-01-29',
#      '2026-01-30',
#      '2026-01-31',
#      '2026-02-01'],
#     'icon': 'circle',
#     'style': {'color': '#CD7F32', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Sierra-at-Tahoe</h1><h2>Score: <b>52.25</b>/100</h2><br>In the Northern California region, you can expect the weather to have <b>Clouds</b> during the 9th week of ski season, which is <b> Jan 26, 2026 to Feb 01, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-119.032, 37.631]},
#    'properties': {'times': ['2026-04-13',
#      '2026-04-14',
#      '2026-04-15',
#      '2026-04-16',
#      '2026-04-17',
#      '2026-04-18',
#      '2026-04-19'],
#     'icon': 'circle',
#     'style': {'color': '#A9A9A9', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Mammoth Mountain</h1><h2>Score: <b>60.04</b>/100</h2><br>In the Northern California region, you can expect the weather to be <b>Clear</b> during the 20th week of ski season, which is <b> Apr 13, 2026 to Apr 19, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.939, 45.159]},
#    'properties': {'times': ['2026-03-09',
#      '2026-03-10',
#      '2026-03-11',
#      '2026-03-12',
#      '2026-03-13',
#      '2026-03-14',
#      '2026-03-15'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Boyne Mountain</h1><h2>Score: <b>58.30</b>/100</h2><br>In the Midwest region, you can expect the weather to have <b>Clouds</b> during the 15th week of ski season, which is <b> Mar 09, 2026 to Mar 15, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-119.032, 37.631]},
#    'properties': {'times': ['2026-02-23',
#      '2026-02-24',
#      '2026-02-25',
#      '2026-02-26',
#      '2026-02-27',
#      '2026-02-28',
#      '2026-03-01'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Mammoth Mountain</h1><h2>Score: <b>53.66</b>/100</h2><br>In the Northern California region, you can expect the weather to be <b>Clear</b> during the 13th week of ski season, which is <b> Feb 23, 2026 to Mar 01, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-120.081, 38.8]},
#    'properties': {'times': ['2026-02-09',
#      '2026-02-10',
#      '2026-02-11',
#      '2026-02-12',
#      '2026-02-13',
#      '2026-02-14',
#      '2026-02-15'],
#     'icon': 'circle',
#     'style': {'color': '#A9A9A9', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Sierra-at-Tahoe</h1><h2>Score: <b>57.68</b>/100</h2><br>In the Northern California region, you can expect the weather to be <b>Clear</b> during the 11th week of ski season, which is <b> Feb 09, 2026 to Feb 15, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-121.678, 44.002]},
#    'properties': {'times': ['2026-01-12',
#      '2026-01-13',
#      '2026-01-14',
#      '2026-01-15',
#      '2026-01-16',
#      '2026-01-17',
#      '2026-01-18'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Mt. Bachelor</h1><h2>Score: <b>35.05</b>/100</h2><br>In the PNW region, you can expect the weather to have <b>Clouds</b> during the 7th week of ski season, which is <b> Jan 12, 2026 to Jan 18, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-111.656, 40.581]},
#    'properties': {'times': ['2026-03-23',
#      '2026-03-24',
#      '2026-03-25',
#      '2026-03-26',
#      '2026-03-27',
#      '2026-03-28',
#      '2026-03-29'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Snowbird</h1><h2>Score: <b>40.07</b>/100</h2><br>In the Rockies region, you can expect the weather to have <b>Clouds</b> during the 17th week of ski season, which is <b> Mar 23, 2026 to Mar 29, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.939, 45.159]},
#    'properties': {'times': ['2026-03-02',
#      '2026-03-03',
#      '2026-03-04',
#      '2026-03-05',
#      '2026-03-06',
#      '2026-03-07',
#      '2026-03-08'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Boyne Mountain</h1><h2>Score: <b>56.56</b>/100</h2><br>In the Midwest region, you can expect the weather to have <b>Clouds</b> during the 14th week of ski season, which is <b> Mar 02, 2026 to Mar 08, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-120.081, 38.8]},
#    'properties': {'times': ['2026-04-13',
#      '2026-04-14',
#      '2026-04-15',
#      '2026-04-16',
#      '2026-04-17',
#      '2026-04-18',
#      '2026-04-19'],
#     'icon': 'circle',
#     'style': {'color': '#CD7F32', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Sierra-at-Tahoe</h1><h2>Score: <b>53.76</b>/100</h2><br>In the Northern California region, you can expect the weather to be <b>Clear</b> during the 20th week of ski season, which is <b> Apr 13, 2026 to Apr 19, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-120.081, 38.8]},
#    'properties': {'times': ['2025-12-08',
#      '2025-12-09',
#      '2025-12-10',
#      '2025-12-11',
#      '2025-12-12',
#      '2025-12-13',
#      '2025-12-14'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Sierra-at-Tahoe</h1><h2>Score: <b>52.28</b>/100</h2><br>In the Northern California region, you can expect the weather to have <b>Clouds</b> during the 2th week of ski season, which is <b> Dec 08, 2025 to Dec 14, 2025</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-111.656, 40.581]},
#    'properties': {'times': ['2026-03-02',
#      '2026-03-03',
#      '2026-03-04',
#      '2026-03-05',
#      '2026-03-06',
#      '2026-03-07',
#      '2026-03-08'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Snowbird</h1><h2>Score: <b>36.48</b>/100</h2><br>In the Rockies region, you can expect the weather to have <b>Clouds</b> during the 14th week of ski season, which is <b> Mar 02, 2026 to Mar 08, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-119.032, 37.631]},
#    'properties': {'times': ['2025-12-08',
#      '2025-12-09',
#      '2025-12-10',
#      '2025-12-11',
#      '2025-12-12',
#      '2025-12-13',
#      '2025-12-14'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Mammoth Mountain</h1><h2>Score: <b>47.99</b>/100</h2><br>In the Northern California region, you can expect the weather to be <b>Clear</b> during the 2th week of ski season, which is <b> Dec 08, 2025 to Dec 14, 2025</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-121.678, 44.002]},
#    'properties': {'times': ['2026-02-02',
#      '2026-02-03',
#      '2026-02-04',
#      '2026-02-05',
#      '2026-02-06',
#      '2026-02-07',
#      '2026-02-08'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Mt. Bachelor</h1><h2>Score: <b>37.26</b>/100</h2><br>In the PNW region, you can expect the weather to have <b>Clouds</b> during the 10th week of ski season, which is <b> Feb 02, 2026 to Feb 08, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-121.678, 44.002]},
#    'properties': {'times': ['2025-12-29',
#      '2025-12-30',
#      '2025-12-31',
#      '2026-01-01',
#      '2026-01-02',
#      '2026-01-03',
#      '2026-01-04'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Mt. Bachelor</h1><h2>Score: <b>39.37</b>/100</h2><br>In the PNW region, you can expect the weather to have <b>Snow</b> during the 5th week of ski season, which is <b> Dec 29, 2025 to Jan 04, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-121.678, 44.002]},
#    'properties': {'times': ['2026-03-23',
#      '2026-03-24',
#      '2026-03-25',
#      '2026-03-26',
#      '2026-03-27',
#      '2026-03-28',
#      '2026-03-29'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Mt. Bachelor</h1><h2>Score: <b>40.45</b>/100</h2><br>In the PNW region, you can expect the weather to have <b>Clouds</b> during the 17th week of ski season, which is <b> Mar 23, 2026 to Mar 29, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.922, 45.469]},
#    'properties': {'times': ['2025-12-08',
#      '2025-12-09',
#      '2025-12-10',
#      '2025-12-11',
#      '2025-12-12',
#      '2025-12-13',
#      '2025-12-14'],
#     'icon': 'circle',
#     'style': {'color': '#EFBF04', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Boyne Highlands</h1><h2>Score: <b>69.81</b>/100</h2><br>In the Midwest region, you can expect the weather to be <b>Clear</b> during the 2th week of ski season, which is <b> Dec 08, 2025 to Dec 14, 2025</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-111.656, 40.581]},
#    'properties': {'times': ['2026-01-05',
#      '2026-01-06',
#      '2026-01-07',
#      '2026-01-08',
#      '2026-01-09',
#      '2026-01-10',
#      '2026-01-11'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Snowbird</h1><h2>Score: <b>29.91</b>/100</h2><br>In the Rockies region, you can expect the weather to have <b>Clouds</b> during the 6th week of ski season, which is <b> Jan 05, 2026 to Jan 11, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.922, 45.469]},
#    'properties': {'times': ['2026-03-02',
#      '2026-03-03',
#      '2026-03-04',
#      '2026-03-05',
#      '2026-03-06',
#      '2026-03-07',
#      '2026-03-08'],
#     'icon': 'circle',
#     'style': {'color': '#EFBF04', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Boyne Highlands</h1><h2>Score: <b>71.10</b>/100</h2><br>In the Midwest region, you can expect the weather to be <b>Clear</b> during the 14th week of ski season, which is <b> Mar 02, 2026 to Mar 08, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-120.081, 38.8]},
#    'properties': {'times': ['2025-12-29',
#      '2025-12-30',
#      '2025-12-31',
#      '2026-01-01',
#      '2026-01-02',
#      '2026-01-03',
#      '2026-01-04'],
#     'icon': 'circle',
#     'style': {'color': '#EFBF04', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Sierra-at-Tahoe</h1><h2>Score: <b>64.33</b>/100</h2><br>In the Northern California region, you can expect the weather to have <b>Clouds</b> during the 5th week of ski season, which is <b> Dec 29, 2025 to Jan 04, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-120.081, 38.8]},
#    'properties': {'times': ['2026-03-09',
#      '2026-03-10',
#      '2026-03-11',
#      '2026-03-12',
#      '2026-03-13',
#      '2026-03-14',
#      '2026-03-15'],
#     'icon': 'circle',
#     'style': {'color': '#CD7F32', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Sierra-at-Tahoe</h1><h2>Score: <b>58.42</b>/100</h2><br>In the Northern California region, you can expect the weather to have <b>Snow</b> during the 15th week of ski season, which is <b> Mar 09, 2026 to Mar 15, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-105.766, 38.487]},
#    'properties': {'times': ['2026-03-16',
#      '2026-03-17',
#      '2026-03-18',
#      '2026-03-19',
#      '2026-03-20',
#      '2026-03-21',
#      '2026-03-22'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Copper Mountain</h1><h2>Score: <b>53.70</b>/100</h2><br>In the Rockies region, you can expect the weather to have <b>Clouds</b> during the 16th week of ski season, which is <b> Mar 16, 2026 to Mar 22, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-121.417, 47.424]},
#    'properties': {'times': ['2026-01-26',
#      '2026-01-27',
#      '2026-01-28',
#      '2026-01-29',
#      '2026-01-30',
#      '2026-01-31',
#      '2026-02-01'],
#     'icon': 'circle',
#     'style': {'color': '#EFBF04', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>The Summit at Snoqualmie</h1><h2>Score: <b>62.65</b>/100</h2><br>In the PNW region, you can expect the weather to be <b>Clear</b> during the 9th week of ski season, which is <b> Jan 26, 2026 to Feb 01, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.922, 45.469]},
#    'properties': {'times': ['2026-01-12',
#      '2026-01-13',
#      '2026-01-14',
#      '2026-01-15',
#      '2026-01-16',
#      '2026-01-17',
#      '2026-01-18'],
#     'icon': 'circle',
#     'style': {'color': '#CD7F32', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Boyne Highlands</h1><h2>Score: <b>53.06</b>/100</h2><br>In the Midwest region, you can expect the weather to have <b>Snow</b> during the 7th week of ski season, which is <b> Jan 12, 2026 to Jan 18, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.922, 45.469]},
#    'properties': {'times': ['2025-12-29',
#      '2025-12-30',
#      '2025-12-31',
#      '2026-01-01',
#      '2026-01-02',
#      '2026-01-03',
#      '2026-01-04'],
#     'icon': 'circle',
#     'style': {'color': '#A9A9A9', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Boyne Highlands</h1><h2>Score: <b>49.28</b>/100</h2><br>In the Midwest region, you can expect the weather to have <b>Snow</b> during the 5th week of ski season, which is <b> Dec 29, 2025 to Jan 04, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-105.766, 38.487]},
#    'properties': {'times': ['2026-03-09',
#      '2026-03-10',
#      '2026-03-11',
#      '2026-03-12',
#      '2026-03-13',
#      '2026-03-14',
#      '2026-03-15'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Copper Mountain</h1><h2>Score: <b>40.24</b>/100</h2><br>In the Rockies region, you can expect the weather to have <b>Clouds</b> during the 15th week of ski season, which is <b> Mar 09, 2026 to Mar 15, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-111.656, 40.581]},
#    'properties': {'times': ['2026-02-23',
#      '2026-02-24',
#      '2026-02-25',
#      '2026-02-26',
#      '2026-02-27',
#      '2026-02-28',
#      '2026-03-01'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Snowbird</h1><h2>Score: <b>55.87</b>/100</h2><br>In the Rockies region, you can expect the weather to have <b>Clouds</b> during the 13th week of ski season, which is <b> Feb 23, 2026 to Mar 01, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-111.656, 40.581]},
#    'properties': {'times': ['2026-01-26',
#      '2026-01-27',
#      '2026-01-28',
#      '2026-01-29',
#      '2026-01-30',
#      '2026-01-31',
#      '2026-02-01'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Snowbird</h1><h2>Score: <b>38.83</b>/100</h2><br>In the Rockies region, you can expect the weather to be <b>Clear</b> during the 9th week of ski season, which is <b> Jan 26, 2026 to Feb 01, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-119.032, 37.631]},
#    'properties': {'times': ['2025-12-22',
#      '2025-12-23',
#      '2025-12-24',
#      '2025-12-25',
#      '2025-12-26',
#      '2025-12-27',
#      '2025-12-28'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Mammoth Mountain</h1><h2>Score: <b>47.04</b>/100</h2><br>In the Northern California region, you can expect the weather to have <b>Clouds</b> during the 4th week of ski season, which is <b> Dec 22, 2025 to Dec 28, 2025</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.939, 45.159]},
#    'properties': {'times': ['2026-01-12',
#      '2026-01-13',
#      '2026-01-14',
#      '2026-01-15',
#      '2026-01-16',
#      '2026-01-17',
#      '2026-01-18'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Boyne Mountain</h1><h2>Score: <b>46.04</b>/100</h2><br>In the Midwest region, you can expect the weather to have <b>Clouds</b> during the 7th week of ski season, which is <b> Jan 12, 2026 to Jan 18, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-119.032, 37.631]},
#    'properties': {'times': ['2026-03-23',
#      '2026-03-24',
#      '2026-03-25',
#      '2026-03-26',
#      '2026-03-27',
#      '2026-03-28',
#      '2026-03-29'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Mammoth Mountain</h1><h2>Score: <b>51.01</b>/100</h2><br>In the Northern California region, you can expect the weather to be <b>Clear</b> during the 17th week of ski season, which is <b> Mar 23, 2026 to Mar 29, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-121.417, 47.424]},
#    'properties': {'times': ['2026-04-06',
#      '2026-04-07',
#      '2026-04-08',
#      '2026-04-09',
#      '2026-04-10',
#      '2026-04-11',
#      '2026-04-12'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>The Summit at Snoqualmie</h1><h2>Score: <b>47.35</b>/100</h2><br>In the PNW region, you can expect the weather to have <b>Rain</b> during the 19th week of ski season, which is <b> Apr 06, 2026 to Apr 12, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.939, 45.159]},
#    'properties': {'times': ['2025-12-15',
#      '2025-12-16',
#      '2025-12-17',
#      '2025-12-18',
#      '2025-12-19',
#      '2025-12-20',
#      '2025-12-21'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Boyne Mountain</h1><h2>Score: <b>41.39</b>/100</h2><br>In the Midwest region, you can expect the weather to have <b>Clouds</b> during the 3th week of ski season, which is <b> Dec 15, 2025 to Dec 21, 2025</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-105.766, 38.487]},
#    'properties': {'times': ['2025-12-29',
#      '2025-12-30',
#      '2025-12-31',
#      '2026-01-01',
#      '2026-01-02',
#      '2026-01-03',
#      '2026-01-04'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Copper Mountain</h1><h2>Score: <b>34.04</b>/100</h2><br>In the Rockies region, you can expect the weather to have <b>Clouds</b> during the 5th week of ski season, which is <b> Dec 29, 2025 to Jan 04, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.922, 45.469]},
#    'properties': {'times': ['2026-01-26',
#      '2026-01-27',
#      '2026-01-28',
#      '2026-01-29',
#      '2026-01-30',
#      '2026-01-31',
#      '2026-02-01'],
#     'icon': 'circle',
#     'style': {'color': '#A9A9A9', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Boyne Highlands</h1><h2>Score: <b>62.22</b>/100</h2><br>In the Midwest region, you can expect the weather to have <b>Clouds</b> during the 9th week of ski season, which is <b> Jan 26, 2026 to Feb 01, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.922, 45.469]},
#    'properties': {'times': ['2026-03-30',
#      '2026-03-31',
#      '2026-04-01',
#      '2026-04-02',
#      '2026-04-03',
#      '2026-04-04',
#      '2026-04-05'],
#     'icon': 'circle',
#     'style': {'color': '#A9A9A9', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Boyne Highlands</h1><h2>Score: <b>62.26</b>/100</h2><br>In the Midwest region, you can expect the weather to have <b>Rain</b> during the 18th week of ski season, which is <b> Mar 30, 2026 to Apr 05, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-120.081, 38.8]},
#    'properties': {'times': ['2025-12-15',
#      '2025-12-16',
#      '2025-12-17',
#      '2025-12-18',
#      '2025-12-19',
#      '2025-12-20',
#      '2025-12-21'],
#     'icon': 'circle',
#     'style': {'color': '#A9A9A9', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Sierra-at-Tahoe</h1><h2>Score: <b>61.16</b>/100</h2><br>In the Northern California region, you can expect the weather to have <b>Clouds</b> during the 3th week of ski season, which is <b> Dec 15, 2025 to Dec 21, 2025</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-120.081, 38.8]},
#    'properties': {'times': ['2026-03-02',
#      '2026-03-03',
#      '2026-03-04',
#      '2026-03-05',
#      '2026-03-06',
#      '2026-03-07',
#      '2026-03-08'],
#     'icon': 'circle',
#     'style': {'color': '#CD7F32', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Sierra-at-Tahoe</h1><h2>Score: <b>61.81</b>/100</h2><br>In the Northern California region, you can expect the weather to be <b>Clear</b> during the 14th week of ski season, which is <b> Mar 02, 2026 to Mar 08, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-121.678, 44.002]},
#    'properties': {'times': ['2025-12-01',
#      '2025-12-02',
#      '2025-12-03',
#      '2025-12-04',
#      '2025-12-05',
#      '2025-12-06',
#      '2025-12-07'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Mt. Bachelor</h1><h2>Score: <b>37.99</b>/100</h2><br>In the PNW region, you can expect the weather to have <b>Clouds</b> during the 1th week of ski season, which is <b> Dec 01, 2025 to Dec 07, 2025</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-119.032, 37.631]},
#    'properties': {'times': ['2026-03-02',
#      '2026-03-03',
#      '2026-03-04',
#      '2026-03-05',
#      '2026-03-06',
#      '2026-03-07',
#      '2026-03-08'],
#     'icon': 'circle',
#     'style': {'color': '#A9A9A9', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Mammoth Mountain</h1><h2>Score: <b>63.34</b>/100</h2><br>In the Northern California region, you can expect the weather to be <b>Clear</b> during the 14th week of ski season, which is <b> Mar 02, 2026 to Mar 08, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-119.032, 37.631]},
#    'properties': {'times': ['2026-03-09',
#      '2026-03-10',
#      '2026-03-11',
#      '2026-03-12',
#      '2026-03-13',
#      '2026-03-14',
#      '2026-03-15'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Mammoth Mountain</h1><h2>Score: <b>46.68</b>/100</h2><br>In the Northern California region, you can expect the weather to have <b>Snow</b> during the 15th week of ski season, which is <b> Mar 09, 2026 to Mar 15, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-111.656, 40.581]},
#    'properties': {'times': ['2026-01-12',
#      '2026-01-13',
#      '2026-01-14',
#      '2026-01-15',
#      '2026-01-16',
#      '2026-01-17',
#      '2026-01-18'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Snowbird</h1><h2>Score: <b>28.02</b>/100</h2><br>In the Rockies region, you can expect the weather to have <b>Clouds</b> during the 7th week of ski season, which is <b> Jan 12, 2026 to Jan 18, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-105.766, 38.487]},
#    'properties': {'times': ['2026-02-02',
#      '2026-02-03',
#      '2026-02-04',
#      '2026-02-05',
#      '2026-02-06',
#      '2026-02-07',
#      '2026-02-08'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Copper Mountain</h1><h2>Score: <b>41.74</b>/100</h2><br>In the Rockies region, you can expect the weather to be <b>Clear</b> during the 10th week of ski season, which is <b> Feb 02, 2026 to Feb 08, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-111.656, 40.581]},
#    'properties': {'times': ['2025-12-29',
#      '2025-12-30',
#      '2025-12-31',
#      '2026-01-01',
#      '2026-01-02',
#      '2026-01-03',
#      '2026-01-04'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Snowbird</h1><h2>Score: <b>33.08</b>/100</h2><br>In the Rockies region, you can expect the weather to have <b>Clouds</b> during the 5th week of ski season, which is <b> Dec 29, 2025 to Jan 04, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-121.417, 47.424]},
#    'properties': {'times': ['2025-12-22',
#      '2025-12-23',
#      '2025-12-24',
#      '2025-12-25',
#      '2025-12-26',
#      '2025-12-27',
#      '2025-12-28'],
#     'icon': 'circle',
#     'style': {'color': '#A9A9A9', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>The Summit at Snoqualmie</h1><h2>Score: <b>54.82</b>/100</h2><br>In the PNW region, you can expect the weather to have <b>Snow</b> during the 4th week of ski season, which is <b> Dec 22, 2025 to Dec 28, 2025</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-121.417, 47.424]},
#    'properties': {'times': ['2025-12-15',
#      '2025-12-16',
#      '2025-12-17',
#      '2025-12-18',
#      '2025-12-19',
#      '2025-12-20',
#      '2025-12-21'],
#     'icon': 'circle',
#     'style': {'color': '#CD7F32', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>The Summit at Snoqualmie</h1><h2>Score: <b>56.79</b>/100</h2><br>In the PNW region, you can expect the weather to have <b>Snow</b> during the 3th week of ski season, which is <b> Dec 15, 2025 to Dec 21, 2025</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-121.417, 47.424]},
#    'properties': {'times': ['2026-04-13',
#      '2026-04-14',
#      '2026-04-15',
#      '2026-04-16',
#      '2026-04-17',
#      '2026-04-18',
#      '2026-04-19'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>The Summit at Snoqualmie</h1><h2>Score: <b>52.28</b>/100</h2><br>In the PNW region, you can expect the weather to have <b>Snow</b> during the 20th week of ski season, which is <b> Apr 13, 2026 to Apr 19, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-105.766, 38.487]},
#    'properties': {'times': ['2025-12-15',
#      '2025-12-16',
#      '2025-12-17',
#      '2025-12-18',
#      '2025-12-19',
#      '2025-12-20',
#      '2025-12-21'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Copper Mountain</h1><h2>Score: <b>38.28</b>/100</h2><br>In the Rockies region, you can expect the weather to have <b>Clouds</b> during the 3th week of ski season, which is <b> Dec 15, 2025 to Dec 21, 2025</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.939, 45.159]},
#    'properties': {'times': ['2026-01-19',
#      '2026-01-20',
#      '2026-01-21',
#      '2026-01-22',
#      '2026-01-23',
#      '2026-01-24',
#      '2026-01-25'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Boyne Mountain</h1><h2>Score: <b>34.70</b>/100</h2><br>In the Midwest region, you can expect the weather to have <b>Clouds</b> during the 8th week of ski season, which is <b> Jan 19, 2026 to Jan 25, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-119.032, 37.631]},
#    'properties': {'times': ['2025-12-15',
#      '2025-12-16',
#      '2025-12-17',
#      '2025-12-18',
#      '2025-12-19',
#      '2025-12-20',
#      '2025-12-21'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Mammoth Mountain</h1><h2>Score: <b>54.23</b>/100</h2><br>In the Northern California region, you can expect the weather to have <b>Clouds</b> during the 3th week of ski season, which is <b> Dec 15, 2025 to Dec 21, 2025</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-121.417, 47.424]},
#    'properties': {'times': ['2026-02-16',
#      '2026-02-17',
#      '2026-02-18',
#      '2026-02-19',
#      '2026-02-20',
#      '2026-02-21',
#      '2026-02-22'],
#     'icon': 'circle',
#     'style': {'color': '#A9A9A9', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>The Summit at Snoqualmie</h1><h2>Score: <b>60.45</b>/100</h2><br>In the PNW region, you can expect the weather to have <b>Clouds</b> during the 12th week of ski season, which is <b> Feb 16, 2026 to Feb 22, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.922, 45.469]},
#    'properties': {'times': ['2026-01-19',
#      '2026-01-20',
#      '2026-01-21',
#      '2026-01-22',
#      '2026-01-23',
#      '2026-01-24',
#      '2026-01-25'],
#     'icon': 'circle',
#     'style': {'color': '#A9A9A9', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Boyne Highlands</h1><h2>Score: <b>55.53</b>/100</h2><br>In the Midwest region, you can expect the weather to have <b>Snow</b> during the 8th week of ski season, which is <b> Jan 19, 2026 to Jan 25, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-105.766, 38.487]},
#    'properties': {'times': ['2026-01-12',
#      '2026-01-13',
#      '2026-01-14',
#      '2026-01-15',
#      '2026-01-16',
#      '2026-01-17',
#      '2026-01-18'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Copper Mountain</h1><h2>Score: <b>27.67</b>/100</h2><br>In the Rockies region, you can expect the weather to have <b>Clouds</b> during the 7th week of ski season, which is <b> Jan 12, 2026 to Jan 18, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.922, 45.469]},
#    'properties': {'times': ['2026-03-09',
#      '2026-03-10',
#      '2026-03-11',
#      '2026-03-12',
#      '2026-03-13',
#      '2026-03-14',
#      '2026-03-15'],
#     'icon': 'circle',
#     'style': {'color': '#EFBF04', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Boyne Highlands</h1><h2>Score: <b>76.75</b>/100</h2><br>In the Midwest region, you can expect the weather to be <b>Clear</b> during the 15th week of ski season, which is <b> Mar 09, 2026 to Mar 15, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-121.678, 44.002]},
#    'properties': {'times': ['2026-01-05',
#      '2026-01-06',
#      '2026-01-07',
#      '2026-01-08',
#      '2026-01-09',
#      '2026-01-10',
#      '2026-01-11'],
#     'icon': 'circle',
#     'style': {'color': '#CD7F32', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Mt. Bachelor</h1><h2>Score: <b>51.20</b>/100</h2><br>In the PNW region, you can expect the weather to have <b>Snow</b> during the 6th week of ski season, which is <b> Jan 05, 2026 to Jan 11, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-105.766, 38.487]},
#    'properties': {'times': ['2025-12-22',
#      '2025-12-23',
#      '2025-12-24',
#      '2025-12-25',
#      '2025-12-26',
#      '2025-12-27',
#      '2025-12-28'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Copper Mountain</h1><h2>Score: <b>32.79</b>/100</h2><br>In the Rockies region, you can expect the weather to have <b>Clouds</b> during the 4th week of ski season, which is <b> Dec 22, 2025 to Dec 28, 2025</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.939, 45.159]},
#    'properties': {'times': ['2025-12-22',
#      '2025-12-23',
#      '2025-12-24',
#      '2025-12-25',
#      '2025-12-26',
#      '2025-12-27',
#      '2025-12-28'],
#     'icon': 'circle',
#     'style': {'color': '#CD7F32', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Boyne Mountain</h1><h2>Score: <b>53.00</b>/100</h2><br>In the Midwest region, you can expect the weather to have <b>Clouds</b> during the 4th week of ski season, which is <b> Dec 22, 2025 to Dec 28, 2025</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-105.766, 38.487]},
#    'properties': {'times': ['2026-03-23',
#      '2026-03-24',
#      '2026-03-25',
#      '2026-03-26',
#      '2026-03-27',
#      '2026-03-28',
#      '2026-03-29'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Copper Mountain</h1><h2>Score: <b>55.90</b>/100</h2><br>In the Rockies region, you can expect the weather to have <b>Clouds</b> during the 17th week of ski season, which is <b> Mar 23, 2026 to Mar 29, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-105.766, 38.487]},
#    'properties': {'times': ['2026-01-05',
#      '2026-01-06',
#      '2026-01-07',
#      '2026-01-08',
#      '2026-01-09',
#      '2026-01-10',
#      '2026-01-11'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Copper Mountain</h1><h2>Score: <b>31.67</b>/100</h2><br>In the Rockies region, you can expect the weather to have <b>Clouds</b> during the 6th week of ski season, which is <b> Jan 05, 2026 to Jan 11, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-120.081, 38.8]},
#    'properties': {'times': ['2026-03-23',
#      '2026-03-24',
#      '2026-03-25',
#      '2026-03-26',
#      '2026-03-27',
#      '2026-03-28',
#      '2026-03-29'],
#     'icon': 'circle',
#     'style': {'color': '#CD7F32', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Sierra-at-Tahoe</h1><h2>Score: <b>61.29</b>/100</h2><br>In the Northern California region, you can expect the weather to be <b>Clear</b> during the 17th week of ski season, which is <b> Mar 23, 2026 to Mar 29, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-111.656, 40.581]},
#    'properties': {'times': ['2026-03-09',
#      '2026-03-10',
#      '2026-03-11',
#      '2026-03-12',
#      '2026-03-13',
#      '2026-03-14',
#      '2026-03-15'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Snowbird</h1><h2>Score: <b>37.55</b>/100</h2><br>In the Rockies region, you can expect the weather to have <b>Clouds</b> during the 15th week of ski season, which is <b> Mar 09, 2026 to Mar 15, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-111.656, 40.581]},
#    'properties': {'times': ['2026-04-06',
#      '2026-04-07',
#      '2026-04-08',
#      '2026-04-09',
#      '2026-04-10',
#      '2026-04-11',
#      '2026-04-12'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Snowbird</h1><h2>Score: <b>44.84</b>/100</h2><br>In the Rockies region, you can expect the weather to have <b>Clouds</b> during the 19th week of ski season, which is <b> Apr 06, 2026 to Apr 12, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-121.678, 44.002]},
#    'properties': {'times': ['2026-04-13',
#      '2026-04-14',
#      '2026-04-15',
#      '2026-04-16',
# ...
#      '2026-03-31',
#      '2026-04-01',
#      '2026-04-02',
#      '2026-04-03',
#      '2026-04-04',
#      '2026-04-05'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>The Summit at Snoqualmie</h1><h2>Score: <b>45.27</b>/100</h2><br>In the PNW region, you can expect the weather to have <b>Rain</b> during the 18th week of ski season, which is <b> Mar 30, 2026 to Apr 05, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-119.032, 37.631]},
#    'properties': {'times': ['2026-02-16',
#      '2026-02-17',
#      '2026-02-18',
#      '2026-02-19',
#      '2026-02-20',
#      '2026-02-21',
#      '2026-02-22'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Mammoth Mountain</h1><h2>Score: <b>53.81</b>/100</h2><br>In the Northern California region, you can expect the weather to have <b>Snow</b> during the 12th week of ski season, which is <b> Feb 16, 2026 to Feb 22, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.939, 45.159]},
#    'properties': {'times': ['2026-02-02',
#      '2026-02-03',
#      '2026-02-04',
#      '2026-02-05',
#      '2026-02-06',
#      '2026-02-07',
#      '2026-02-08'],
#     'icon': 'circle',
#     'style': {'color': '#CD7F32', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Boyne Mountain</h1><h2>Score: <b>55.03</b>/100</h2><br>In the Midwest region, you can expect the weather to have <b>Clouds</b> during the 10th week of ski season, which is <b> Feb 02, 2026 to Feb 08, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-120.081, 38.8]},
#    'properties': {'times': ['2026-03-30',
#      '2026-03-31',
#      '2026-04-01',
#      '2026-04-02',
#      '2026-04-03',
#      '2026-04-04',
#      '2026-04-05'],
#     'icon': 'circle',
#     'style': {'color': '#EFBF04', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Sierra-at-Tahoe</h1><h2>Score: <b>73.17</b>/100</h2><br>In the Northern California region, you can expect the weather to be <b>Clear</b> during the 18th week of ski season, which is <b> Mar 30, 2026 to Apr 05, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-105.766, 38.487]},
#    'properties': {'times': ['2025-12-01',
#      '2025-12-02',
#      '2025-12-03',
#      '2025-12-04',
#      '2025-12-05',
#      '2025-12-06',
#      '2025-12-07'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Copper Mountain</h1><h2>Score: <b>41.22</b>/100</h2><br>In the Rockies region, you can expect the weather to have <b>Clouds</b> during the 1th week of ski season, which is <b> Dec 01, 2025 to Dec 07, 2025</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-121.417, 47.424]},
#    'properties': {'times': ['2026-01-05',
#      '2026-01-06',
#      '2026-01-07',
#      '2026-01-08',
#      '2026-01-09',
#      '2026-01-10',
#      '2026-01-11'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>The Summit at Snoqualmie</h1><h2>Score: <b>46.63</b>/100</h2><br>In the PNW region, you can expect the weather to have <b>Snow</b> during the 6th week of ski season, which is <b> Jan 05, 2026 to Jan 11, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-119.032, 37.631]},
#    'properties': {'times': ['2026-03-16',
#      '2026-03-17',
#      '2026-03-18',
#      '2026-03-19',
#      '2026-03-20',
#      '2026-03-21',
#      '2026-03-22'],
#     'icon': 'circle',
#     'style': {'color': '#EFBF04', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Mammoth Mountain</h1><h2>Score: <b>68.34</b>/100</h2><br>In the Northern California region, you can expect the weather to be <b>Clear</b> during the 16th week of ski season, which is <b> Mar 16, 2026 to Mar 22, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-105.766, 38.487]},
#    'properties': {'times': ['2026-04-13',
#      '2026-04-14',
#      '2026-04-15',
#      '2026-04-16',
#      '2026-04-17',
#      '2026-04-18',
#      '2026-04-19'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Copper Mountain</h1><h2>Score: <b>43.31</b>/100</h2><br>In the Rockies region, you can expect the weather to have <b>Clouds</b> during the 20th week of ski season, which is <b> Apr 13, 2026 to Apr 19, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.939, 45.159]},
#    'properties': {'times': ['2026-02-16',
#      '2026-02-17',
#      '2026-02-18',
#      '2026-02-19',
#      '2026-02-20',
#      '2026-02-21',
#      '2026-02-22'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Boyne Mountain</h1><h2>Score: <b>50.36</b>/100</h2><br>In the Midwest region, you can expect the weather to have <b>Clouds</b> during the 12th week of ski season, which is <b> Feb 16, 2026 to Feb 22, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-120.081, 38.8]},
#    'properties': {'times': ['2026-03-16',
#      '2026-03-17',
#      '2026-03-18',
#      '2026-03-19',
#      '2026-03-20',
#      '2026-03-21',
#      '2026-03-22'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Sierra-at-Tahoe</h1><h2>Score: <b>60.23</b>/100</h2><br>In the Northern California region, you can expect the weather to be <b>Clear</b> during the 16th week of ski season, which is <b> Mar 16, 2026 to Mar 22, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-121.678, 44.002]},
#    'properties': {'times': ['2026-04-06',
#      '2026-04-07',
#      '2026-04-08',
#      '2026-04-09',
#      '2026-04-10',
#      '2026-04-11',
#      '2026-04-12'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Mt. Bachelor</h1><h2>Score: <b>52.07</b>/100</h2><br>In the PNW region, you can expect the weather to have <b>Snow</b> during the 19th week of ski season, which is <b> Apr 06, 2026 to Apr 12, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.922, 45.469]},
#    'properties': {'times': ['2026-04-06',
#      '2026-04-07',
#      '2026-04-08',
#      '2026-04-09',
#      '2026-04-10',
#      '2026-04-11',
#      '2026-04-12'],
#     'icon': 'circle',
#     'style': {'color': '#A9A9A9', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Boyne Highlands</h1><h2>Score: <b>62.81</b>/100</h2><br>In the Midwest region, you can expect the weather to be <b>Clear</b> during the 19th week of ski season, which is <b> Apr 06, 2026 to Apr 12, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-105.766, 38.487]},
#    'properties': {'times': ['2026-02-09',
#      '2026-02-10',
#      '2026-02-11',
#      '2026-02-12',
#      '2026-02-13',
#      '2026-02-14',
#      '2026-02-15'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Copper Mountain</h1><h2>Score: <b>34.64</b>/100</h2><br>In the Rockies region, you can expect the weather to have <b>Clouds</b> during the 11th week of ski season, which is <b> Feb 09, 2026 to Feb 15, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.922, 45.469]},
#    'properties': {'times': ['2025-12-22',
#      '2025-12-23',
#      '2025-12-24',
#      '2025-12-25',
#      '2025-12-26',
#      '2025-12-27',
#      '2025-12-28'],
#     'icon': 'circle',
#     'style': {'color': '#EFBF04', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Boyne Highlands</h1><h2>Score: <b>63.84</b>/100</h2><br>In the Midwest region, you can expect the weather to have <b>Clouds</b> during the 4th week of ski season, which is <b> Dec 22, 2025 to Dec 28, 2025</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-120.081, 38.8]},
#    'properties': {'times': ['2025-12-22',
#      '2025-12-23',
#      '2025-12-24',
#      '2025-12-25',
#      '2025-12-26',
#      '2025-12-27',
#      '2025-12-28'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Sierra-at-Tahoe</h1><h2>Score: <b>48.39</b>/100</h2><br>In the Northern California region, you can expect the weather to have <b>Rain</b> during the 4th week of ski season, which is <b> Dec 22, 2025 to Dec 28, 2025</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-121.417, 47.424]},
#    'properties': {'times': ['2025-12-08',
#      '2025-12-09',
#      '2025-12-10',
#      '2025-12-11',
#      '2025-12-12',
#      '2025-12-13',
#      '2025-12-14'],
#     'icon': 'circle',
#     'style': {'color': '#CD7F32', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>The Summit at Snoqualmie</h1><h2>Score: <b>54.10</b>/100</h2><br>In the PNW region, you can expect the weather to have <b>Clouds</b> during the 2th week of ski season, which is <b> Dec 08, 2025 to Dec 14, 2025</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-121.417, 47.424]},
#    'properties': {'times': ['2026-03-09',
#      '2026-03-10',
#      '2026-03-11',
#      '2026-03-12',
#      '2026-03-13',
#      '2026-03-14',
#      '2026-03-15'],
#     'icon': 'circle',
#     'style': {'color': '#A9A9A9', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>The Summit at Snoqualmie</h1><h2>Score: <b>63.08</b>/100</h2><br>In the PNW region, you can expect the weather to have <b>Clouds</b> during the 15th week of ski season, which is <b> Mar 09, 2026 to Mar 15, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-121.678, 44.002]},
#    'properties': {'times': ['2026-03-09',
#      '2026-03-10',
#      '2026-03-11',
#      '2026-03-12',
#      '2026-03-13',
#      '2026-03-14',
#      '2026-03-15'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Mt. Bachelor</h1><h2>Score: <b>50.60</b>/100</h2><br>In the PNW region, you can expect the weather to have <b>Clouds</b> during the 15th week of ski season, which is <b> Mar 09, 2026 to Mar 15, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-121.678, 44.002]},
#    'properties': {'times': ['2026-03-16',
#      '2026-03-17',
#      '2026-03-18',
#      '2026-03-19',
#      '2026-03-20',
#      '2026-03-21',
#      '2026-03-22'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Mt. Bachelor</h1><h2>Score: <b>44.71</b>/100</h2><br>In the PNW region, you can expect the weather to have <b>Clouds</b> during the 16th week of ski season, which is <b> Mar 16, 2026 to Mar 22, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-119.032, 37.631]},
#    'properties': {'times': ['2026-01-19',
#      '2026-01-20',
#      '2026-01-21',
#      '2026-01-22',
#      '2026-01-23',
#      '2026-01-24',
#      '2026-01-25'],
#     'icon': 'circle',
#     'style': {'color': '#CD7F32', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Mammoth Mountain</h1><h2>Score: <b>51.29</b>/100</h2><br>In the Northern California region, you can expect the weather to be <b>Clear</b> during the 8th week of ski season, which is <b> Jan 19, 2026 to Jan 25, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-111.656, 40.581]},
#    'properties': {'times': ['2026-03-16',
#      '2026-03-17',
#      '2026-03-18',
#      '2026-03-19',
#      '2026-03-20',
#      '2026-03-21',
#      '2026-03-22'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Snowbird</h1><h2>Score: <b>47.36</b>/100</h2><br>In the Rockies region, you can expect the weather to have <b>Clouds</b> during the 16th week of ski season, which is <b> Mar 16, 2026 to Mar 22, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-121.417, 47.424]},
#    'properties': {'times': ['2026-03-16',
#      '2026-03-17',
#      '2026-03-18',
#      '2026-03-19',
#      '2026-03-20',
#      '2026-03-21',
#      '2026-03-22'],
#     'icon': 'circle',
#     'style': {'color': '#CD7F32', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>The Summit at Snoqualmie</h1><h2>Score: <b>60.57</b>/100</h2><br>In the PNW region, you can expect the weather to have <b>Snow</b> during the 16th week of ski season, which is <b> Mar 16, 2026 to Mar 22, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-111.656, 40.581]},
#    'properties': {'times': ['2025-12-22',
#      '2025-12-23',
#      '2025-12-24',
#      '2025-12-25',
#      '2025-12-26',
#      '2025-12-27',
#      '2025-12-28'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Snowbird</h1><h2>Score: <b>33.56</b>/100</h2><br>In the Rockies region, you can expect the weather to have <b>Snow</b> during the 4th week of ski season, which is <b> Dec 22, 2025 to Dec 28, 2025</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-111.656, 40.581]},
#    'properties': {'times': ['2026-02-02',
#      '2026-02-03',
#      '2026-02-04',
#      '2026-02-05',
#      '2026-02-06',
#      '2026-02-07',
#      '2026-02-08'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Snowbird</h1><h2>Score: <b>35.62</b>/100</h2><br>In the Rockies region, you can expect the weather to have <b>Clouds</b> during the 10th week of ski season, which is <b> Feb 02, 2026 to Feb 08, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-119.032, 37.631]},
#    'properties': {'times': ['2026-01-26',
#      '2026-01-27',
#      '2026-01-28',
#      '2026-01-29',
#      '2026-01-30',
#      '2026-01-31',
#      '2026-02-01'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Mammoth Mountain</h1><h2>Score: <b>47.11</b>/100</h2><br>In the Northern California region, you can expect the weather to be <b>Clear</b> during the 9th week of ski season, which is <b> Jan 26, 2026 to Feb 01, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-121.678, 44.002]},
#    'properties': {'times': ['2025-12-08',
#      '2025-12-09',
#      '2025-12-10',
#      '2025-12-11',
#      '2025-12-12',
#      '2025-12-13',
#      '2025-12-14'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Mt. Bachelor</h1><h2>Score: <b>36.05</b>/100</h2><br>In the PNW region, you can expect the weather to have <b>Clouds</b> during the 2th week of ski season, which is <b> Dec 08, 2025 to Dec 14, 2025</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.939, 45.159]},
#    'properties': {'times': ['2026-04-13',
#      '2026-04-14',
#      '2026-04-15',
#      '2026-04-16',
#      '2026-04-17',
#      '2026-04-18',
#      '2026-04-19'],
#     'icon': 'circle',
#     'style': {'color': '#FFFFFF', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Boyne Mountain</h1><h2>Score: <b>38.52</b>/100</h2><br>In the Midwest region, you can expect the weather to have <b>Clouds</b> during the 20th week of ski season, which is <b> Apr 13, 2026 to Apr 19, 2026</b>.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-84.922, 45.469]},
#    'properties': {'times': ['2026-02-02',
#      '2026-02-03',
#      '2026-02-04',
#      '2026-02-05',
#      '2026-02-06',
#      '2026-02-07',
#      '2026-02-08'],
#     'icon': 'circle',
#     'style': {'color': '#A9A9A9', 'radius': 20, 'font-size': '14px'},
#     'tooltip': '<h1>Boyne Highlands</h1><h2>Score: <b>55.26</b>/100</h2><br>In the Midwest region, you can expect the weather to have <b>Clouds</b> during the 10th week of ski season, which is <b> Feb 02, 2026 to Feb 08, 2026</b>.'}}]}

# %%
base_map = folium.Map(location=[39.83, -98.58], zoom_start=5, tiles="cartodb positron")

# %%
TimestampedGeoJson(
    geojson_data,
    period="P1D",
    add_last_point=True,
    auto_play=False,
    loop=False,
    max_speed=1,
    loop_button=True,
    date_options="YYYY-MM-DD",
    time_slider_drag_update=True,
    duration="P1D",
).add_to(base_map)

# %%
for _, row in loc_lookup.iterrows():
    popup_text = f"Region: {row['us_region']}\nTimezone: {row['original_timezone']}"

    folium.Marker(
        location=[(row['latitude']), row['longitude']],
        tooltip=row['ski_resort'],
        popup=popup_text,
        icon=folium.Icon(icon="person-skiing", prefix="fa", )
    ).add_to(base_map)

# %%
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_482b7bedcf16893713212b8593e481a9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jquery/3.7.1/jquery.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.10.2/jquery-ui.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/iso8601-js-period@0.2.1/iso8601.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.18.1/moment.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/highlight.js/8.4/styles/default.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet-timedimension@1.1.1/dist/leaflet.timedimension.control.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_482b7bedcf16893713212b8593e481a9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_482b7bedcf16893713212b8593e481a9 = L.map(
#                 &quot;map_482b7bedcf16893713212b8593e481a9&quot;,
#                 {
#                     center: [39.83, -98.58],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bd5b757efcdb5fd7dd78ef94bc5e5c75 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bd5b757efcdb5fd7dd78ef94bc5e5c75.addTo(map_482b7bedcf16893713212b8593e481a9);
#
#
#             L.Control.TimeDimensionCustom = L.Control.TimeDimension.extend({
#                 _getDisplayDateFormat: function(date){
#                     var newdate = new moment(date);
#                     console.log(newdate)
#                     return newdate.format(&quot;YYYY-MM-DD&quot;);
#                 }
#             });
#             map_482b7bedcf16893713212b8593e481a9.timeDimension = L.timeDimension(
#                 {
#                     period: &quot;P1D&quot;,
#                 }
#             );
#             var timeDimensionControl = new L.Control.TimeDimensionCustom(
#                 {
#   &quot;position&quot;: &quot;bottomleft&quot;,
#   &quot;minSpeed&quot;: 0.1,
#   &quot;maxSpeed&quot;: 1,
#   &quot;autoPlay&quot;: false,
#   &quot;loopButton&quot;: true,
#   &quot;timeSliderDragUpdate&quot;: true,
#   &quot;speedSlider&quot;: true,
#   &quot;playerOptions&quot;: {
#   &quot;transitionTime&quot;: 200,
#   &quot;loop&quot;: false,
#   &quot;startOver&quot;: true,
# },
# }
#             );
#             map_482b7bedcf16893713212b8593e481a9.addControl(this.timeDimensionControl);
#
#             var geoJsonLayer = L.geoJson({&quot;type&quot;: &quot;FeatureCollection&quot;, &quot;features&quot;: [{&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [-121.417, 47.424]}, &quot;properties&quot;: {&quot;times&quot;: [&quot;2026-01-12&quot;, &quot;2026-01-13&quot;, &quot;2026-01-14&quot;, &quot;2026-01-15&quot;, &quot;2026-01-16&quot;, &quot;2026-01-17&quot;, &quot;2026-01-18&quot;], &quot;icon&quot;: &quot;circle&quot;, &quot;style&quot;: {&quot;color&quot;: &quot;#A9A9A9&quot;, &quot;radius&quot;: 20, &quot;font-size&quot;: &quot;14px&quot;}, &quot;tooltip&quot;: &quot;&lt;h1&gt;The Summit at Snoqualmie&lt;/h1&gt;&lt;h2&gt;Score: &lt;b&gt;62.57&lt;/b&gt;/100&lt;/h2&gt;&lt;br&gt;In the PNW region, you can expect the weather to have &lt;b&gt;Clouds&lt;/b&gt; during the 7th week of ski season, which is &lt;b&gt; Jan 12, 2026 to Jan 18, 2026&lt;/b&gt;.&quot;}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [-84.922, 45.469]}, &quot;properties&quot;: {&quot;times&quot;: [&quot;2026-03-23&quot;, &quot;2026-03-24&quot;, &quot;2026-03-25&quot;, &quot;2026-03-26&quot;, &quot;2026-03-27&quot;, &quot;2026-03-28&quot;, &quot;2026-03-29&quot;], &quot;icon&quot;: &quot;circle&quot;, &quot;style&quot;: {&quot;color&quot;: &quot;#EFBF04&quot;, &quot;radius&quot;: 20, &quot;font-size&quot;: &quot;14px&quot;}, &quot;tooltip&quot;: &quot;&lt;h1&gt;Boyne Highlands&lt;/h1&gt;&lt;h2&gt;Score: &lt;b&gt;62.10&lt;/b&gt;/100&lt;/h2&gt;&lt;br&gt;In the Midwest region, you can expect the weather to have &lt;b&gt;Clouds&lt;/b&gt; during the 17th week of ski season, which is &lt;b&gt; Mar 23, 2026 to Mar 29, 2026&lt;/b&gt;.&quot;}}, {&quot;type&quot;: &quot;Feature&quot;, &quot;geometry&quot;: {&quot;type&quot;: &quot;Point&quot;, &quot;coordinates&quot;: [-119.032, 37.631]}, &quot;properties&quot;: {&quot;times&quot;: [&quot;2026-02-02&quot;, &quot;20

# %%
base_map.save('output/ski_map.html')
